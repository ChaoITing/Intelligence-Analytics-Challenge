# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/chaoiting/Desktop/competition/new_df_impute.csv')
df
# Out:
#      Unnamed: 0                           Countries  \
# 0             0                         Afghanistan
# 1             1                             Albania
# 2             2                             Algeria
# 3             3                             Andorra
# 4             4                              Angola
# ..          ...                                 ...
# 192         192  Venezuela (Bolivarian Republic of)
# 193         193                            Viet Nam
# 194         194                               Yemen
# 195         195                              Zambia
# 196         196                            Zimbabwe
#
#                                 Area  mortality_rate     Life  Primary_school  \
# 0                         South Asia            70.0  63.6730       89.746724
# 1    Eastern Europe and Central Asia            14.0  78.3450       95.517310
# 2       Middle East and North Africa            25.0  76.0780       97.062150
# ...

# %%
country = df.iloc[:, 1].tolist()
area = df.iloc[:, 2].tolist()
geo = pd.DataFrame(np.array([country, area]), 
                         index = ['country', 'area'])
geo = geo.T
geo
# Out:
#                                 country                             area
# 0                           Afghanistan                       South Asia
# 1                               Albania  Eastern Europe and Central Asia
# 2                               Algeria     Middle East and North Africa
# 3                               Andorra                   Western Europe
# 4                                Angola      Eastern and Southern Africa
# ..                                  ...                              ...
# 192  Venezuela (Bolivarian Republic of)      Latin America and Caribbean
# 193                            Viet Nam            East Asia and Pacific
# 194                               Yemen     Middle East and North Africa
# 195                              Zambia      Eastern and Southern Africa
# 196                            Zimbabwe      Eastern and Southern Africa
#
# [197 rows x 2 columns]

# %%
geo.to_csv(r'/Users/chaoiting/Desktop/competition/geo.csv')
